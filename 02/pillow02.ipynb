# %%
from PIL import Image
import os
import os.path

# %%
rootdir = r'D:/code/cave/stuffed_toys'
for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        print('parent is :' + parent)
        print('filename is :' + filename)
        currentPath = os.path.join(parent, filename)
        print('the fulll name of the file is :' + currentPath)
 
        im = Image.open(currentPath)
        out = im.transpose(Image.FLIP_LEFT_RIGHT)
        newname=r"D:/code/cave/stuffed_toys"+'\\'+filename+".jpg"
        out.save(newname)
# Out:
# parent is :D:/code/cave/stuffed_toys
# filename is :st1.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st1.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st10.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st10.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st11.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st11.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st12.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st12.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st13.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st13.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st14.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st14.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st15.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st15.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st16.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st16.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st17.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st17.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st18.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st18.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st2.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st2.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st3.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st3.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st4.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st4.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st5.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st5.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st6.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st6.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st7.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st7.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st8.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st8.jpg
# parent is :D:/code/cave/stuffed_toys
# filename is :st9.jpg
# the fulll name of the file is :D:/code/cave/stuffed_toys\st9.jpg

# %%
rootdir = r'D:/code/cave/superballs'
for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        print('parent is :' + parent)
        print('filename is :' + filename)
        currentPath = os.path.join(parent, filename)
        print('the fulll name of the file is :' + currentPath)
 
        im = Image.open(currentPath)
        out = im.transpose(Image.FLIP_LEFT_RIGHT)
        newname=r"D:/code/cave/superballs"+'\\'+filename+".jpg"
        out.save(newname)
# Out:
# parent is :D:/code/cave/superballs
# filename is :sb1.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb1.jpg
# parent is :D:/code/cave/superballs
# filename is :sb10.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb10.jpg
# parent is :D:/code/cave/superballs
# filename is :sb11.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb11.jpg
# parent is :D:/code/cave/superballs
# filename is :sb12.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb12.jpg
# parent is :D:/code/cave/superballs
# filename is :sb13.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb13.jpg
# parent is :D:/code/cave/superballs
# filename is :sb14.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb14.jpg
# parent is :D:/code/cave/superballs
# filename is :sb15.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb15.jpg
# parent is :D:/code/cave/superballs
# filename is :sb16.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb16.jpg
# parent is :D:/code/cave/superballs
# filename is :sb17.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb17.jpg
# parent is :D:/code/cave/superballs
# filename is :sb18.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb18.jpg
# parent is :D:/code/cave/superballs
# filename is :sb2.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb2.jpg
# parent is :D:/code/cave/superballs
# filename is :sb3.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb3.jpg
# parent is :D:/code/cave/superballs
# filename is :sb4.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb4.jpg
# parent is :D:/code/cave/superballs
# filename is :sb5.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb5.jpg
# parent is :D:/code/cave/superballs
# filename is :sb6.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb6.jpg
# parent is :D:/code/cave/superballs
# filename is :sb7.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb7.jpg
# parent is :D:/code/cave/superballs
# filename is :sb8.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb8.jpg
# parent is :D:/code/cave/superballs
# filename is :sb9.jpg
# the fulll name of the file is :D:/code/cave/superballs\sb9.jpg

# %%
rootdir = r'D:/code/cave/watercolors'
for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        print('parent is :' + parent)
        print('filename is :' + filename)
        currentPath = os.path.join(parent, filename)
        print('the fulll name of the file is :' + currentPath)
 
        im = Image.open(currentPath)
        out = im.transpose(Image.FLIP_LEFT_RIGHT)
        newname=r"D:/code/cave/watercolors"+'\\'+filename+".jpg"
        out.save(newname)
# Out:
# parent is :D:/code/cave/watercolors
# filename is :w1.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w1.jpg
# parent is :D:/code/cave/watercolors
# filename is :w10.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w10.jpg
# parent is :D:/code/cave/watercolors
# filename is :w11.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w11.jpg
# parent is :D:/code/cave/watercolors
# filename is :w12.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w12.jpg
# parent is :D:/code/cave/watercolors
# filename is :w13.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w13.jpg
# parent is :D:/code/cave/watercolors
# filename is :w14.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w14.jpg
# parent is :D:/code/cave/watercolors
# filename is :w15.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w15.jpg
# parent is :D:/code/cave/watercolors
# filename is :w16.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w16.jpg
# parent is :D:/code/cave/watercolors
# filename is :w17.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w17.jpg
# parent is :D:/code/cave/watercolors
# filename is :w18.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w18.jpg
# parent is :D:/code/cave/watercolors
# filename is :w2.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w2.jpg
# parent is :D:/code/cave/watercolors
# filename is :w3.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w3.jpg
# parent is :D:/code/cave/watercolors
# filename is :w4.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w4.jpg
# parent is :D:/code/cave/watercolors
# filename is :w5.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w5.jpg
# parent is :D:/code/cave/watercolors
# filename is :w6.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w6.jpg
# parent is :D:/code/cave/watercolors
# filename is :w7.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w7.jpg
# parent is :D:/code/cave/watercolors
# filename is :w8.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w8.jpg
# parent is :D:/code/cave/watercolors
# filename is :w9.jpg
# the fulll name of the file is :D:/code/cave/watercolors\w9.jpg

# %%
rootdir = r'D:/code/cave/oil_painting'
for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        print('parent is :' + parent)
        print('filename is :' + filename)
        currentPath = os.path.join(parent, filename)
        print('the fulll name of the file is :' + currentPath)
 
        im = Image.open(currentPath)
        out = im.transpose(Image.FLIP_LEFT_RIGHT)
        newname=r"D:/code/cave/oil_painting"+'\\'+filename+".jpg"
        out.save(newname)
# Out:
# parent is :D:/code/cave/oil_painting
# filename is :o1.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o1.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o10.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o10.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o11.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o11.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o12.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o12.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o13.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o13.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o14.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o14.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o15.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o15.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o16.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o16.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o17.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o17.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o18.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o18.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o2.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o2.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o3.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o3.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o4.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o4.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o5.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o5.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o6.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o6.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o7.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o7.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o8.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o8.jpg
# parent is :D:/code/cave/oil_painting
# filename is :o9.jpg
# the fulll name of the file is :D:/code/cave/oil_painting\o9.jpg
